# %%
### 20250422 html 첫 수업!!! ㅇ0ㅇ

# %% [markdown]
# 바탕화면에 새로만들기 해서, txt 파일 생성!
# 이후 안에 텍스트를 적어넣고, 확장자를 html로 바꾸면...!!
# 바로 홈페이지 웹을 만들어볼 수 있다구 !!!

# %% [markdown]
# ![image.png](attachment:b4c6f801-a1ed-4980-9f58-b526206cbdb4.png)

# %%
# 태그 !!!

<시작> : </끝> !
; 꺾쇠를 기준으로 시작과 끝!!!!

<a></a>
<div</div>
<span></div>

<br/>
<img/>
<input/>

# %% [markdown]
# #### Vs code로 시작하기~

# %%
## 확장 설치!!!!
Prettier - code formatter - 다른 언어도 사용 가능 !!
Live server *** 중요 !!!! (html 할 때 !!)
HTML CSS Support - html
Material icon theme
Color highlight - html, css
Git graph - git

# %%
## Vs code에서 작성!!
 ; ! 쳐서 emmet 약자 선택!!! 
그럼 기초적인 html 구조가 작성이 된다 !!!

# %%
<body></body> 사이에 원하는 텍스트 넣고 alt + L + o 단축기 누르기 !!!

# %% [markdown]
# ![image.png](attachment:1e5cd09e-6c87-474a-8fd6-0dce5259dec9.png)

# %%
# 태그 추가
<a href=""></a>
<div 속성은 여기에></div>

# %%
# Lorem
이거 Lorem 치면 또 약어 비슷하게 나옴 !!
Lorem ipsum dolor sit amet consectetur adipisicing elit. Tempore reprehenderit natus debitis impedit quis, ipsam quam sint. At iure cupiditate quis culpa consectetur enim praesentium, laborum facilis harum itaque? Magnam explicabo eveniet laudantium, tempora consectetur soluta maiores laboriosam voluptates autem a mollitia commodi, labore porro, facere dolorum illo dicta non.

# %%
<span></span> 이걸 더 자주 쓴다나봐~

# %%
<p style = "background-color : rgb(205, 208, 255)"> 이런 식으로 색도 채워넣을 수 있다 !!
